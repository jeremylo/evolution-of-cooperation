# %%
from society.agent import Agent
from society.simulations import BasicSimulation
from society.strategies.gameplay.constant import AllC, AllD
from society.strategies.gameplay.tft import TitForTat
from society.strategies.gameplay.random import RandomGameplayStrategy
from society.strategies.selection.greedy import GreedySelectionStrategy, EGreedySelectionStrategy
from society.visualisation.network import *

import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (8, 6)

# %%
sim = BasicSimulation(
    [
        Agent(GreedySelectionStrategy(), AllC()),                       # 0
        Agent(GreedySelectionStrategy(), AllD()),                       # 1
        Agent(GreedySelectionStrategy(), RandomGameplayStrategy()),     # 2
        Agent(GreedySelectionStrategy(), TitForTat()),                  # 3
        Agent(EGreedySelectionStrategy(), AllC()),                      # 0
        Agent(EGreedySelectionStrategy(), AllD()),                      # 1
        Agent(EGreedySelectionStrategy(), RandomGameplayStrategy()),    # 2
        Agent(EGreedySelectionStrategy(), TitForTat()),                 # 3
    ]
)

for i in range(50):
    sim.play_round()

    if i % 1 == 0:
        G = make_graph(sim.returns)
        plot_returns(G)
# Out:
# c:\Users\jerem\miniconda3\envs\climatehack\lib\site-packages\numpy\core\numeric.py:1211: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   a = asanyarray(a)
# c:\Users\jerem\Documents\GitHub\evolution-of-cooperation\society\visualisation\network.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
# Model-free conventions in multi-agent reinforcement learning with
# heterogeneous preferences
