# %%
from itertools import chain
from random import random

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from tqdm.notebook import tqdm

from society.action import Action
from society.agent import Agent
from society.agents.constant import AllC, AllD
from society.agents.qlearning import DoubleTabularQLearner, TabularQLearner
from society.agents.random import Random
from society.agents.tft import TitForTat
from society.simulations.adaptive import AdaptiveSimulation
from society.visualisation.network import *

plt.rcParams["figure.figsize"] = (12, 5)

# %%
def generate_population(population):
    agents = [
        DoubleTabularQLearner(lookback=2, epsilon=0.1, learning_rate=0.05, discount_factor=0.99)
        for _ in range(population)
    ]

    G = nx.complete_graph(population)

    weights_matrix = np.zeros((population, population))
    for u, v, d in G.edges(data=True):
        weights_matrix[u, v] = weights_matrix[v, u] = 1
        try:
            d["weight"] = weights_matrix[u, v]
        except:
            d["weight"] = 0

    return agents, weights_matrix, G

# %%
# _, _, G = generate_population(32)

# nx.draw(G, pos=nx.spring_layout(G), font_color="white", with_labels=True)

# %%
def compute_policies(agents):
    policies = [
        agent._q_table.argmax(axis=-1)
        if hasattr(agent, "_q_table") else None
        for agent in agents
    ]

    return [
        "".join(
            [
                ("C", "D")[policy[i, j]]
                for i in range(4)
                for j in range(4)
                # for k in range(4)
            ]
        )
        if policy is not None else "OTHER"
        for policy in policies
    ]

def calculate_cooperativeness(history):
    count = history.count(Action.COOPERATE)

    return count / len(history)

# %%
PAYOFF_LABELS = ["(C, C)", "(C, D)", "(D, C)", "(D, D)"]

# %%
POPULATION = (256,)
ROUNDS = 6_000

run_rewards = []
run_cumulative_rewards = []
run_reward_histories = []
run_policies = []

for run in range(10):
    epoch_rewards = []

    # Generate a new population
    agents, weights_matrix, G = generate_population(*POPULATION)

    # Run a number of rounds
    sim = AdaptiveSimulation(agents, weights_matrix)

    # Run the simulation
    sim.reset()
    for i in tqdm(range(ROUNDS), desc=f"Run {run + 1}"):
        r = sim.play_round(train=True)
        epoch_rewards.append(r)

    # Store results
    run_rewards.append(sim.rewards)
    # run_action_histories.append(sim.action_histories)
    run_reward_histories.append(sim.reward_histories)
    run_policies.append(compute_policies(agents))

    # Output statistics for the best and worst agents
    cumulative_rewards = [(i, sum(history)) for i, history in enumerate(sim.reward_histories)]
    cumulative_rewards.sort(key=lambda x: x[1], reverse=True)

    tqdm.write(
        f"BEST AGENT ({cumulative_rewards[0][0]}): {cumulative_rewards[0][1]} ({calculate_cooperativeness(list(chain(*sim.action_histories[cumulative_rewards[0][0]])))}, {run_policies[-1][cumulative_rewards[0][0]]})"
    )
    tqdm.write(
        f"WORST AGENT ({cumulative_rewards[-1][0]}): {cumulative_rewards[-1][1]} ({calculate_cooperativeness(list(chain(*sim.action_histories[cumulative_rewards[-1][0]])))}, {run_policies[-1][cumulative_rewards[-1][0]]})"
    )

    for rh in sim.reward_histories:
        plt.plot(np.cumsum(rh))
    
    plt.show()

    plt.plot(sim.differences)
    plt.show()

    plt.plot(epoch_rewards)
    plt.show()

    M = sim.produce_weight_matrix()
    for row in M:
        sns.kdeplot(row)

    plt.show()
# Out:
# Run 1:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (127): 36976 (0.9513814684780949, CCCCCCCCCCCCCCCC)
# WORST AGENT (18): 28061 (0.5094747551825003, DDDDCCCCCCCCCCCC)
# Run 2:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (240): 36413 (0.9508272769444874, CCCCCCCCCCCCCCCC)
# WORST AGENT (190): 26728 (0.3279144087814367, DCDCDCCCCCDCCCCC)
# Run 3:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (29): 36712 (0.9496898690558235, CCCCCCCCCCCCCCCC)
# WORST AGENT (130): 28028 (0.5266766392420843, DCDDCCCDCCCCCCCC)
# Run 4:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (77): 36825 (0.9495984703632887, CCCCCCCCCCCCCCCC)
# WORST AGENT (224): 27249 (0.4498189342990171, DCDCCCCCDDCCCDCC)
# Run 5:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (191): 36486 (0.945865369527695, CCCCCDCCCCCCCCCC)
# WORST AGENT (156): 26722 (0.45293881376355605, DCDCCCCDDCCCCCCC)
# Run 6:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (27): 36711 (0.9433774581069707, CCCCCDCCCCCDCCCC)
# WORST AGENT (197): 26347 (0.3522167487684729, DCDCCDCCDCDCCCCC)
# Run 7:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (186): 36436 (0.9491538580965688, CCCCCCCCCCCCCCCC)
# WORST AGENT (145): 27748 (0.5537627786673236, DCDCCCDCCCCCCCCC)
# Run 8:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (26): 36675 (0.9527456536723596, CCCCCCCCCCCCCCCC)
# WORST AGENT (92): 27367 (0.5675156174915906, DCDCCCCCCCCCCCCC)
# Run 9:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (131): 36604 (0.9538855678906917, CCCCCCCCCCCCCCCC)
# WORST AGENT (247): 26520 (0.47190419792077903, DCDCCCCCDCCCCCCC)
# Run 10:   0%|          | 0/6000 [00:00<?, ?it/s]
# BEST AGENT (200): 36722 (0.9382476308839521, CCCCCCCCCCCCCDCC)
# WORST AGENT (28): 26326 (0.3880378313573998, DCDCCCCCCCDCCCCC)

# %%
G = nx.from_numpy_matrix(np.matrix(sim.produce_weight_matrix()), create_using=nx.DiGraph)

# %%
# from datetime import datetime

# dt = datetime.isoformat(datetime.now()).replace(":", "-").replace("T", " ")

# nx.drawing.nx_pydot.write_dot(G, f"{dt}.dot")

# %%
# plot_matrix(sim.frequencies, digits=0, figsize=(60, 36))

# %%
M = sim.produce_weight_matrix()

M
# Out:
# array([[0.        , 0.8836    , 0.6232687 , ..., 0.84833795, 0.62673611,
#         0.38525565],
#        [0.8836    , 0.        , 0.47928994, ..., 0.87890625, 0.89197531,
#         0.05      ],
#        [0.6232687 , 0.47928994, 0.        , ..., 0.62520281, 0.73469388,
#         0.40111111],
#        ...,
#        [0.84833795, 0.87890625, 0.62520281, ..., 0.        , 0.71818443,
#         0.28994083],
#        [0.62673611, 0.89197531, 0.73469388, ..., 0.71818443, 0.        ,
#         0.40742417],
#        [0.38525565, 0.05      , 0.40111111, ..., 0.28994083, 0.40742417,
#         0.        ]])

# %%
import seaborn as sns

# %%
weights = sim.calculate_weights()

weights
# Out:
# array([[0.05      , 0.8836    , 0.6232687 , ..., 0.84833795, 0.62673611,
#         0.38525565],
#        [0.8836    , 0.05      , 0.47928994, ..., 0.87890625, 0.89197531,
#         0.05      ],
#        [0.6232687 , 0.47928994, 0.05      , ..., 0.62520281, 0.73469388,
#         0.40111111],
#        ...,
#        [0.84833795, 0.87890625, 0.62520281, ..., 0.05      , 0.71818443,
#         0.28994083],
#        [0.62673611, 0.89197531, 0.73469388, ..., 0.71818443, 0.05      ,
#         0.40742417],
#        [0.38525565, 0.05      , 0.40111111, ..., 0.28994083, 0.40742417,
#         0.05      ]])

# %%
# K = nx.Graph()
# K.add_weighted_edges_from([
#     (i, j, weights[i, j] + weights[j, i])
#     for i in range(POPULATION[0])
#     for j in range(i + 1, POPULATION[0])
#     if i != j and weights[i, j] > 0.7 and weights[j, i] > 0.7
# ])

# nx.drawing.nx_pydot.write_dot(K, f"{dt} - reduced.dot")

# %%
sim.action_histories[0][2]
# Out:
# [<Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.DEFECT: 1>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.DEFECT: 1>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.DEFECT: 1>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.DEFECT: 1>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.DEFECT: 1>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>,
#  <Action.COOPERATE: 0>]

# %%
cumulative_rewards[0][0]
# Out:
# 200

# %%
if hasattr(agents[cumulative_rewards[0][0]], "_q_table"):
    print(agents[cumulative_rewards[0][0]]._q_table)
# Out:
# [[[2.81969943e+02 2.18503001e+02]
#   [2.57574901e+02 3.66466888e+01]
#   [2.31439303e+02 1.33485558e+01]
#   [4.36298948e+01 2.50000000e-01]]
#
#  [[2.73452896e+02 1.09650460e+02]
#   [1.73732709e+02 9.08436600e+00]
#   [1.16373775e+02 1.79424555e+00]
#   [1.35411282e+01 0.00000000e+00]]
#
#  [[2.62870794e+02 5.93590612e+01]
#   [1.67567375e+02 5.53289768e+00]
#   [7.98530636e+01 3.07940148e+01]
#   [1.88182532e+01 0.00000000e+00]]
#
#  [[1.51168319e+02 5.17086571e+00]
#   [0.00000000e+00 6.67386362e+00]
#   [3.84244160e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00]]]

# %%
agents[cumulative_rewards[4][0]].play_move([Action.COOPERATE, Action.COOPERATE], [Action.COOPERATE, Action.COOPERATE])
# Out:
# <Action.COOPERATE: 0>

# %%
if hasattr(agents[1], "_q_table"):
    print(agents[1]._q_table)
# Out:
# [[[2.80112858e+02 2.12163465e+02]
#   [2.57003728e+02 5.10271709e+01]
#   [2.34529605e+02 1.65510250e+01]
#   [5.48563874e+01 5.00000000e-02]]
#
#  [[2.70328612e+02 7.25172621e+01]
#   [1.83681119e+02 8.61696187e+00]
#   [1.25772727e+02 7.73408093e-01]
#   [6.46156326e+00 0.00000000e+00]]
#
#  [[2.64690338e+02 6.39147265e+01]
#   [1.70671006e+02 3.75615636e+00]
#   [7.84008706e+01 3.28966826e+00]
#   [7.66124504e+00 0.00000000e+00]]
#
#  [[1.56363438e+02 0.00000000e+00]
#   [1.94001936e+01 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00]
#   [2.65420650e+00 0.00000000e+00]]]

# %%
# from datetime import datetime
# import pickle

# with open(f"results - {datetime.isoformat(datetime.now()).replace(':', '-')}.pickle", "wb") as f:
#     pickle.dump({
#         "rewards": run_rewards,
#         "cumulative_rewards": run_cumulative_rewards,
#         # "action_histories": run_action_histories,
#         "reward_histories": run_reward_histories,
#         "policies": run_policies,
#     }, f)

# %%
cumulative_reward_policy_ranks = {}
cumulative_reward_policies = {}

for policies, reward_histories in zip(run_policies, run_reward_histories):
    cumulative_rewards = [(i, sum(history)) for i, history in enumerate(reward_histories)]
    cumulative_rewards.sort(key=lambda x: x[1], reverse=True)

    for rank, (i, cumulative_reward) in enumerate(cumulative_rewards):
        policy = policies[i]

        if policy not in cumulative_reward_policy_ranks:
            cumulative_reward_policy_ranks[policy] = []
            cumulative_reward_policies[policy] = []

        cumulative_reward_policy_ranks[policy].append(rank + 1)
        cumulative_reward_policies[policy].append(cumulative_reward)

mean_cumulative_reward_policy_ranks = {policy: np.mean(ranks) for policy, ranks in cumulative_reward_policy_ranks.items()}
mean_cumulative_reward_policies = {policy: np.mean(rewards) for policy, rewards in cumulative_reward_policies.items()}

# %%
for policy in sorted(mean_cumulative_reward_policy_ranks, key=lambda x: mean_cumulative_reward_policy_ranks[x]):
    print(f"{mean_cumulative_reward_policy_ranks[policy]:<24} {policy}")
# Out:
# 3.0                      CCCCCDCCCDCCCCCD
# 3.0                      CCCCCDCDCCCCCCCD
# 5.0                      CCCCCDCCCCCCCCCD
# 6.0                      CCCCCCCDCCCDCDCC
# 11.0                     CCCDCDCDCCCCCCCC
# 16.0                     CCCDCCCDCCCCDDCC
# 21.0                     CCCCCDDCCCCCCDCC
# 22.0                     CCDCCCDDCCCCCCCC
# 25.0                     CCCCCCDDCDCCCCCC
# 30.0                     CCCDCCCCCCCCCCDD
# 33.0                     CCCCCCCCCCDCCCDC
# 34.0                     CCCCCDCDCDCCCCCC
# 37.0                     CCCCCDCCCCCDDCCC
# 41.5                     CCCCCCCDCCCCCCCD
# 43.0                     CCDDCDCDCCCDCCCC
# 45.0                     CCCCCDCCDCDCCCCC
# 47.0                     CCCDCCCDCCCCCDCC
# 47.0                     CCCCCCDDCCCCCDCC
# 52.2                     CCCDCCCCCCCCDCCC
# 54.0                     CCCCCDDCCCCCCCCD
# 55.2                     CCCCCCDCCCCDCCCC
# 59.0                     CCCCCCCCCCCDCCDC
# 60.0                     CCCCCCCCCCCCCCDD
# 60.0                     CCCCCDCCCDCCCCCC
# 61.0                     CCCDCCCCCCDCCCDC
# 62.0                     CCCDCCCCDCCCCCCD
# 63.0                     CCCCDCCCCCCCCCCD
# 63.07575757575758        CCCCCDCCCCCCCCCC
# 64.0                     CCCCCDCCCCCCDCCC
# 64.0                     CCCDCCDDCCDCCCCC
# 64.25                    CCCCCCCCCDCCCDCC
# 70.0                     CCCDCCDCCCCCDCDC
# 73.0                     CCCDCCCCCCCCCCDC
# 73.0                     CCCCDCCCCCDCCDCC
# 78.42857142857143        CCCCCDCCCCCCCDCC
# 78.85714285714286        CCCCCDCCCCCDCCCC
# 79.0                     CCCCCCCCCCCCDCDC
# 80.0                     CCCCCDDCCCCCCCCC
# 81.0                     CDCCCCCCCCCDCDCC
# 82.0                     CCCDCDCCCDCCCCCC
# 83.8974358974359         CCCCCCCCCCCCCCDC
# 84.0                     CCCDCCCCCCDCCCCC
# 85.0                     CCCCCCCCCCDDCCCC
# 86.30909090909091        CCCCCCCCCCCDCCCC
# 247.0                    DCCCDCCCCCCCCCDC
# 247.0                    DCCCCDDCCCCCCCCC
# 247.0                    DCCCCCCCDCCCDCCC
# 247.0                    DCCCDCCCDCCCCCCC
# 247.25                   DCCDCCCCCCCCCCCC
# 247.75                   DCCCCCCCCCDCCCCC
# 248.0                    DDCDCCDCCCCCCCCC
# 248.5                    DCCCCCCDCDCCCCCC
# 248.66666666666666       DCCCCCCCCCCDCCCC
# 249.0                    DCCDCDCCCDCCCCCD
# 250.0                    DDCCCCCCCDCCCDCC
# 251.0                    DCCCCCCCDCCCCCDC
# 251.0                    DCCDCCCDCCCCCCCC
# 252.0                    DDCCCCDCCDDCCCCD
# 252.0                    DCCDCCCDCCCDCCCC
# 252.0                    DCCCCDCCDDCCCDCC
# 252.0                    DCCCCCCCDCCCCCCD
# 252.0                    DCCCCCCCDCCCDDCC
# 252.0                    DCCCCDCCDDCCCCCC
# 252.0                    DDDCCDCCCDCCCCCC
# 253.0                    DCDDCCCCCCCCCCCC
# 253.0                    DCDCCCDCCCCCDCCC
# 253.0                    DCDCCCCCDCDDCCCC
# 253.25                   DCCCCCCCDCCCCCCC
# 253.5                    DCDCDCCCCCCCCCCC
# 254.0                    DCDCCCCCCCCCDCCC
# 254.0                    DCCCCCCDDCDCCCDD
# 254.0                    DCDDCCCCCCCDCCCC
# 254.5                    DCDCCCDCCCCCCCCC
# 254.66666666666666       DCDCCCCCCCCCCCCC
# 255.0                    DDDCCCCCCCCCCCDC
# 255.0                    DCDCDCCCCCCDCCDC
# 255.0                    DCDCDCCCCCCCCCCD
# 255.0                    DCDCCCCDCCCCCCCC
# 255.0                    DCCCCCCCDCDCDCCC
# 255.0                    DCDCCDCCCCCCCCCC
# 255.0                    DDDCCCCCCCCCCCCC
# 255.0                    DCDCDCCCCCDCCDCC
# 255.5                    DCDDCCCDCCCCCCCC
# 256.0                    DDDDCCCCCCCCCCCC
# 256.0                    DCDCDCCCCCDCCCCC
# 256.0                    DCDCCCCCDDCCCDCC
# 256.0                    DCDCCCCDDCCCCCCC
# 256.0                    DCDCCDCCDCDCCCCC
# 256.0                    DCDCCCCCDCCCCCCC
# 256.0                    DCDCCCCCCCDCCCCC

# %%
for policy in sorted(mean_cumulative_reward_policies, key=lambda x: mean_cumulative_reward_policies[x], reverse=True):
    print(f"{mean_cumulative_reward_policies[policy]:<24} {policy}")
# Out:
# 36613.0                  CCCCCDCDCCCCCCCD
# 36513.0                  CCCCCDCCCCCCCCCD
# 36482.0                  CCCCCCCDCCCDCDCC
# 36403.0                  CCCCCDCCCDCCCCCD
# 36229.0                  CCCDCDCDCCCCCCCC
# 36191.0                  CCCDCCCDCCCCDDCC
# 36125.0                  CCDCCCDDCCCCCCCC
# 36087.0                  CCCCCCDDCDCCCCCC
# 36034.0                  CCCDCCCCCCCCCCDD
# 35962.0                  CCCCCDDCCCCCCDCC
# 35910.0                  CCCCCDCDCDCCCCCC
# 35894.0                  CCCCCDCCDCDCCCCC
# 35831.0                  CCCCCCCCCCDCCCDC
# 35057.22222222222        CCCCDCCCCDCCCCCC
# 35046.2                  CCDCCCCCCDCCCCCC
# 35045.0                  CCDCCDCCCDCCCDCC
# 35026.333333333336       CCDDCCCDCCCCCCCC
# 35026.0                  CCDCCDCCCCCDCCCC
# 35026.0                  CDCCCCCCDDCCCCCC
# 35025.0                  CDCCCCDCCCCCCCDC
# 35015.0                  CDCCCCCCCCCCCCDC
# 35012.6                  CCCCCCCCDCDCCCCC
# 35010.0                  CDDDCCCCCCCCCDCC
# 35009.1                  CDCCCCCCCCCCCDCC
# 35007.0                  CCCCDDCCDCCCCCCC
# 35006.0                  CCCDCCCCCCCCCDDC
# 35003.0                  CCCDCCCCCDCCCCCD
# 34996.0                  CCDCCDCCDCCCCCCC
# 34994.6                  CCCCDCCCCCCCDCCC
# 34975.75                 CCCCDCCDCCCCCCCC
# 34975.0                  CCCCDCCCCCCCDDCC
# 34972.666666666664       CCCCCCCCCCCDCCCD
# 34966.0                  CCCCCDDCCDCCCCCC
# 34964.0                  CCCCCCCCCCCCDDCC
# 34961.0                  CCCDCDCCCCCDCCCC
# 34960.4                  CCCCDCCCCCCDCCCC
# 34941.0                  CCDCCCCDCCCDCCCD
# 34936.0                  CCCCCCCCDDCCCCCC
# 34932.0                  CCDDCCCDCCCCCCCD
# 34916.75                 CCDDCCCCCCCCCCCC
# 34915.5                  CDCCCCCCDCCCCDCC
# 34908.2                  CCDCCCCCCCCDCCCC
# 34908.0                  CCCCDCCCCCCCCCDC
# 34903.444444444445       CCCCDDCCCCCCCCCC
# 34901.31746031746        CCCCDCCCCCCCCCCC
# 34896.0                  CCDDCCDCCCCCCCCD
# 34896.0                  CCCCCDCDDCCCCCCC
# 34894.0                  CCCCCCDDDCCCDCCC
# 34885.378787878784       CDCCCCCCCCCCCCCC
# 34877.0                  CCCCCCCCDCCCCCCD
# 34872.545454545456       CCDCCCCCCCCCCCCC
# 34872.0                  CCCCDCCCDCDCCCCC
# 34871.0                  CCDDCCDCCCCCCCCC
# 34868.4                  CDCCCCCCCCCCDCCC
# 34865.0                  CCCCCCCDCCCDCCDC
# 34858.0                  CCDCCCCCCCDCDCDC
# 34839.3                  CCDCCCDCCCCCCCCC
# 34838.0                  CDCCDDCCCDCCDDCC
# 34837.0                  CDCDCDCDCCCCCCCD
# 34836.0                  CCCCCDCDCCCCCCDC
# 34836.0                  CDDCCCCCCCCCCCDC
# 34822.0                  CCCCCCCCCDCDCDCC
# 34820.0                  CCDDCCCCCCDCCCCC
# 34816.0                  CCDCCCCDCCCCCCCC
# 34813.0                  CDDCCDCCCCCCCDCC
# 34809.0                  CCDCCCCDCCCCCCDC
# 34806.0                  CCCCDCDCCCCCCCCC
# 34804.7                  CCDCCCCCCCDCCCCC
# 34792.8                  CDCCCCCDCCCCCCCC
# 34790.0                  CCCDDCCDCCCCCCCC
# 34787.0                  CCDDCCCCCCCDCCCD
# 34777.0                  CCDCCCDCCCCCDCCC
# 34776.0                  CCCDDCCCCCCCCDCC
# 34771.5                  CCDCCCCCCCDCCCDC
# 34759.0                  CCCCDCCCCCCDCCDC
# 34759.0                  CCCDCCCCCCCDCCDC
# 34742.0                  CCCCDDCCCCCCCDCC
# 34740.0                  CCCCDDCCCCCDCCCC
# 34736.5                  CCDCCCCCCDCCDCCC
# 34731.0                  CCCCCCCCCDCDDCCC
# 34721.142857142855       CCCDDCCCCCCCCCCC
# 34720.0                  CCCCDCCCCDCCCCCD
# 34718.0                  CCCCDDCCCCCCDDCC
# 34708.0                  CDCCCCCCCCCDDCCC
# 34708.0                  CCCCDCCDCCCCCCCD
# 34706.25                 CCDCCCCCCCCCDCCC
# 34702.57142857143        CDCDCCCCCCCCCCCC
# 34691.0                  CDCCCCCCCCDCCDCC
# 34689.0                  CCCCCCCCCDCCDCCC
# 34688.0                  CCCCCCCCDCCDCCCC
# 34682.0                  CDCCDDCCCCCCCCCC
# 34673.0                  CDDCCCDCCCCCCCCC
# 34672.0                  CCCCCCDCCCCDDCCC
# 34662.0                  CCCDDCCCCCCCCCDC
# 34657.0                  CCDCCCCDCCCCCCCD
# 34654.0                  CCDCDCCDDCCCCCCC
# 34647.0                  CDCCCCCCCDCDCCCC
# 34638.0                  CDCCCDCCDDCCCCCC
# 34629.0                  CCDCCCDCCCCCCCDC
# 34627.0                  CCDCCCCCCCCCCCCD
# 34601.0                  CDDCCDCCCCCCCCCC
# 34586.0                  CDCCCDCCCCCDCCDC
# 34584.666666666664       CCCCDCCCCCCCCDCC
# 34579.0                  CCDCDCDCCDCCCDCC
# 34578.0                  CDCCCCDCCCCCCDCC
# 34576.0                  CDCDCCCDCCCCCCDC
# 34572.5                  CDCCCCCCCDCCCCCC
# 34548.0                  CCDCCCCCCCCCDCCD
# 34536.0                  CCCCDCCCDCCCCCCC
# 34536.0                  CCCCDCCDCCCCCCDC
# 34527.0                  CDDCCCDDCDCCCCCC
# 34500.0                  CCCDDDCCCCCDCCCC
# 34494.2                  CDCCCDCCCDCCCCCC
# 34486.5                  CCCCDCCCCCDCCCCC
# 34486.0                  CDCCCCDDCCCCDCDC
# 34475.0                  CCCCDCDCCDCDCCCC
# 34469.0                  CCDCDDCCCCCCCDCC
# 34469.0                  CCDDCCCCCCCCCCCD
# 34463.857142857145       CCDCCCCCDCCCCCCC
# 34455.0                  CDDDCCDCCCCCCCDC
# 34409.0                  CCCDDCDCCCCCCCCC
# 34408.0                  CDDCCCCCCCCCCCCC
# 34386.57142857143        CDCCDCCCCCCCCCCC
# 34385.5                  CDCCCCCCDCCCCCCC
# 34379.0                  CDCCCCCCCCCCDDCC
# 34373.0                  CDCCCCDCCCCDCCDC
# 34371.0                  CDDCCCCCCDCCDCCC
# 34362.0                  CCDDCDCDCCCCCCCC
# 34359.5                  CCDCCCDCCCDCCCCC
# 34358.142857142855       CDCCCCDCCCCCCCCC
# 34351.0                  CCCCDCCCDCCDCCCC
# 34345.25                 CCDCCCCCCCCCCCDC
# 34344.0                  CCDCDDCCCCCCCCDC
# 34337.0                  CCDCCCCCDCDDCCCC
# 34330.0                  CDDCCCCCCCCDCCCC
# 34326.5                  CDCCCCCCCDCCCDCC
# 34310.5                  CDCCCCCDCCCDCCCC
# 34302.0                  CDCDCCDDCCCCCCCD
# 34291.0                  CDCCCCDCCCCCDCCC
# 34290.0                  CCDDCDCCCCDCCCCC
# 34281.0                  CDCCCCCDCDCCCCCC
# 34273.0                  CDDCCCCCCDCCCCCC
# 34249.0                  CDCCCCDCDCCCCCCC
# 34242.0                  CCDCCCDCDCDCCCCD
# 34235.0                  CDCDCCCCDCDCCCDC
# 34231.0                  CDDCCCDCCCCDCDCC
# 34159.0                  CCDCCCDCCCCCCDCC
# 34147.0                  CDCCDCDCCCCCCCCC
# 34132.0                  CDDDCCCCCCCCCCCC
# 34126.25                 CCDCCCCCCCDDCCCC
# 34119.0                  CDDCCDCCCCCDCCCC
# 34111.0                  CCDCCCCCCDDCCCCC
# 34091.0                  CDCDCCCCDCCCCCCC
# 34086.0                  CDCCDCCCCCCCCDCC
# 34083.0                  CDDCCCCCCCDCDCCC
# 34066.0                  CDCDCCDCCCCDCCCC
# 34039.0                  CCCCDCCCDCCCDCCC
# 34007.5                  CCCCDCCCDDCCCCCC
# 33994.57142857143        CCDCDCCCCCCCCCCC
# 33994.0                  CCDCCDDCCCDDCCCC
# 33974.0                  CCDCCCCDCCCCDCCC
# 33893.0                  CDCCCCDCDCCCDCCC
# 33877.0                  CCDCDCCCCCCDCCCC
# 33852.0                  CDCCCCDDCDDDCCCC
# 33838.0                  CDCDCDCCDCCCCCCC
# 33826.666666666664       CCDCCCCDCCDCCCCC
# 33796.0                  CCCCDCDDDCCCCCCC
# 33725.0                  CCDCDDCCCCCCCCCC
# 33722.0                  CDDCDCCCCCCCCCCC
# 33714.0                  CDDCCCCDCCCCCCCD
# 33615.0                  CDDCCCCDCCDDCCCC
# 33605.0                  CDCCCDDCCCCCCCCC
# 33598.0                  CDDCCCDCCCCDCCCC
# 33593.0                  CDCDDCDCCCCCCCCC
# 33590.0                  CDDCCCCCCCDCCCCC
# 33577.0                  CDDCCCCCCCCCCDCD
# 33563.0                  CCDCDCCCCDCCCCCC
# 33478.0                  CDCDCDCCDCCDCCCD
# 33424.0                  CCDCDCCCCCCCDCCC
# 33410.0                  CDDCCDCDCCDCCCDC
# 33350.0                  CCCDCCCDCDCCCCCC
# 33251.0                  CDCCCCCDCDCCCDCC
# 33218.0                  CCDCDCCCCCDCCDCC
# 33192.0                  CDDCCCCCCDDCCCCC
# 32814.0                  CCDCDCCCDCCDCDCC
# 30944.0                  DCCCCDCCCCCCDDCC
# 30845.0                  DDCCDCCCCCCCCCDC
# 30614.0                  DCCCCDCCCCCDCDCC
# 30540.666666666668       DCCCDDCCCCCCCCCC
# 30358.25                 DCCCCCDCCCCCCCCC
# 30354.0                  DCCDCCCCCCCDCCCC
# 30272.0                  DCCDCCCCCCCCDCCD
# 30267.0                  DCCCCDCCCCCCDCCC
# 30217.0                  DCCCCCCCCCDCDCCC
# 30179.0                  DCCCCCCCCDCDCCCC
# 30163.0                  DCCCDCCCCCCCDDCC
# 30137.0                  DCCCCCCCCDCCCCDC
# 30116.0                  DCCCCCCCCDCCDCCC
# 30107.0                  DCCCCCCCCCCCCCDC
# 30105.0                  DDCCCDCDCDCCCCCC
# 30087.0                  DDCCCDCCCCCCCCCC
# 30079.5                  DCCDCCCCCCCCCDCC
# 30073.0                  DDCCCCCDCCCDCCCC
# 30071.454545454544       DCCCCCCCCCCCDCCC
# 30062.666666666668       DCCCCCCDCCCCCCCC
# 30051.222222222223       DCCCCCCCCCCCCDCC
# 30049.571428571428       DDCCCCCCCCCCCCCC
# 30020.0                  DCCCDCCDCCCCCCCC
# 30010.5                  DCCCCDCCCCCCCCCC
# 30008.2                  DCCCDCCCCCCCCCCC
# 30005.0                  DCCCCCCCCCCDDCCC
# 29980.0                  DCCCCDCCCCCCCCDC
# 29975.0                  DCCCDCCCCCCCCDCC
# 29960.0                  DCCCCCCDCCCDCCCC
# 29947.5                  DCCCDCCCCCDCCCCC
# 29935.0                  DCCCCDCCCCCCCCCD
# 29920.0                  DDCCDCCCCCCCCCCC
# 29915.0                  DDCCDDCCCCCCCCCC
# 29894.476923076923       DCCCCCCCCCCCCCCC
# 29886.0                  DCCCCCCDCCCCDCCC
# 29881.0                  DCCCCCCCCCCCCDDC
# 29866.0                  DCCDCDCDCCDCCCCD
# 29863.0                  DCCCCDCCCDCCCCCC
# 29840.0                  DCCDDCCCCCCDCCCC
# 29830.5                  DDCCCCCCCCCCCDCC
# 29826.0                  DCCCDCCCDCCCCCCC
# 29822.0                  DCCCCCCCCCDCCDCC
# 29821.125                DCCCCCCCCCCCCCCD
# 29812.0                  DDCDCCCCCCCCCCCC
# 29803.0                  DDCDCCDCCCCCCCCC
# 29753.666666666668       DCCDCCCCCCCCCCCD
# 29747.0                  DCCCCCCDCDCCCCCC
# 29736.5                  DCCDCCCCCCCCCCCC
# 29733.0                  DCCCDCCCCCCCCCDC
# 29732.0                  DCCDCCCCCCCDDCCC
# 29718.5                  DCCCCDDCCCCCCCCC
# 29708.333333333332       DCCCCCCCCCCDCCCC
# 29671.666666666668       DCCCCCCCCDCCCCCC
# 29656.0                  DDCCCCCCCDCCCDCC
# 29577.0                  DCCDCDCCCDCCCCCD
# 29575.125                DCCCCCCCCCDCCCCC
# 29526.0                  DCCCCDCCDDCCCCCC
# 29486.0                  DDCCCCDCCDDCCCCD
# 29419.0                  DCCCCCCDCCCCCDCC
# 29411.0                  DCCDCCCDCCCCCCCC
# 29347.0                  DCCCDCDCDCCCCCCC
# 29334.0                  DDCCCCDCDCCCCCCC
# 29265.0                  DCCCCCCCDCCCCCCC
# 29263.0                  DCCCCDCCDDCCCDCC
# 29201.0                  DCCCCCCCDCCCDCCC
# 29120.5                  DCCCCCCCDCCCCCCD
# 29074.0                  DCCDCCCDCCCDCCCC
# 28987.0                  DCCCCCCCDCCCCCDC
# 28877.0                  DCCCCCCCDCCCDDCC
# 28652.0                  DCCCCCCCDCDCDCCC
# 28377.0                  DCCCCCCDDCDCCCDD
# 28210.0                  DCDCDCCCCCCDCCDC
# 28168.0                  DDDCCDCCCDCCCCCC
# 28093.0                  DCDCCCCCDCDDCCCC
# 28089.5                  DCDCCCDCCCCCDCCC
# 28061.0                  DDDDCCCCCCCCCCCC
# 27937.0                  DCDDCCCCCCCCCCCC
# 27910.0                  DCDCDCCCCCCCCCCD
# 27875.5                  DCDCCCDCCCCCCCCC
# 27848.0                  DCDDCCCCCCCDCCCC
# 27830.0                  DCDCCCCCCCCCDCCC
# 27823.0                  DDDCCCCCCCCCCCDC
# 27695.5                  DCDCDCCCCCCCCCCC
# 27681.0                  DCDDCCCDCCCCCCCC
# 27569.0                  DCDCCDCCCCCCCCCC
# 27455.0                  DCDCCCCDCCCCCCCC
# 27418.0                  DDDCCCCCCCCCCCCC
# 27403.666666666668       DCDCCCCCCCCCCCCC
# 27249.0                  DCDCCCCCDDCCCDCC
# 26844.0                  DCDCDCCCCCDCCDCC
# 26728.0                  DCDCDCCCCCDCCCCC
# 26722.0                  DCDCCCCDDCCCCCCC
# 26520.0                  DCDCCCCCDCCCCCCC
# 26347.0                  DCDCCDCCDCDCCCCC
# 26326.0                  DCDCCCCCCCDCCCCC

# %%
compute_policies([agents[cumulative_rewards[0][0]]])[0]
# Out:
# 'CCCCCCCCCCCCCDCC'

# %%
if hasattr(agents[cumulative_rewards[0][0]], "_q_table"):
    print(agents[cumulative_rewards[0][0]]._q_table)
# Out:
# [[[2.81969943e+02 2.18503001e+02]
#   [2.57574901e+02 3.66466888e+01]
#   [2.31439303e+02 1.33485558e+01]
#   [4.36298948e+01 2.50000000e-01]]
#
#  [[2.73452896e+02 1.09650460e+02]
#   [1.73732709e+02 9.08436600e+00]
#   [1.16373775e+02 1.79424555e+00]
#   [1.35411282e+01 0.00000000e+00]]
#
#  [[2.62870794e+02 5.93590612e+01]
#   [1.67567375e+02 5.53289768e+00]
#   [7.98530636e+01 3.07940148e+01]
#   [1.88182532e+01 0.00000000e+00]]
#
#  [[1.51168319e+02 5.17086571e+00]
#   [0.00000000e+00 6.67386362e+00]
#   [3.84244160e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00]]]

# %%
from itertools import product

P = compute_policies([agents[cumulative_rewards[0][0]]])[0]

for m, p in zip(product(PAYOFF_LABELS, PAYOFF_LABELS), P):
    print(m, "=>", p)
# Out:
# ('(C, C)', '(C, C)') => C
# ('(C, C)', '(C, D)') => C
# ('(C, C)', '(D, C)') => C
# ('(C, C)', '(D, D)') => C
# ('(C, D)', '(C, C)') => C
# ('(C, D)', '(C, D)') => C
# ('(C, D)', '(D, C)') => C
# ('(C, D)', '(D, D)') => C
# ('(D, C)', '(C, C)') => C
# ('(D, C)', '(C, D)') => C
# ('(D, C)', '(D, C)') => C
# ('(D, C)', '(D, D)') => C
# ('(D, D)', '(C, C)') => C
# ('(D, D)', '(C, D)') => D
# ('(D, D)', '(D, C)') => C
# ('(D, D)', '(D, D)') => C
